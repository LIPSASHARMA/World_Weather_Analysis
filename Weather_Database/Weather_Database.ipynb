# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 706

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=69b00f4f34b26e2ee477369387e8b56e

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ahipara
# Processing Record 2 of Set 1 | cervo
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | gamba
# Processing Record 5 of Set 1 | uvat
# Processing Record 6 of Set 1 | ayr
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | bushenyi
# Processing Record 9 of Set 1 | sete lagoas
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | pangai
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | lerwick
# Processing Record 16 of Set 1 | broken hill
# Processing Record 17 of Set 1 | saint-georges
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | petrolina
# Processing Record 22 of Set 1 | lagoa
# Processing Record 23 of Set 1 | korem
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | havre-saint-pierre
# Processing Record 26 of Set 1 | ngunguru
# Processing Record 27 of Set 1 | morondava
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | mezen
# Processing Record 34 of Set 1 | durban
# Processing Record 35 of Set 1 | wattegama
# Processing Record 36 of Set 1 | norton
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 1 | hobyo
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | namatanai
# Processing Record 44 of Set 1 | bonfim
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | bud
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | asfi
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | fiditi
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | urumqi
# Processing Record 5 of Set 2 | aripuana
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | clyde river
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | umm bab
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | vestmannaeyjar
# Processing Record 12 of Set 2 | birao
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | fuyu
# Processing Record 15 of Set 2 | kerema
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | tura
# Processing Record 18 of Set 2 | carutapera
# Processing Record 19 of Set 2 | omsukchan
# Processing Record 20 of Set 2 | ulaangom
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | vao
# Processing Record 25 of Set 2 | dakar
# Processing Record 26 of Set 2 | touros
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | fuzhou
# Processing Record 29 of Set 2 | rio gallegos
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | iwaki
# Processing Record 32 of Set 2 | colac
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | port-cartier
# Processing Record 35 of Set 2 | sao joao do paraiso
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | buraydah
# Processing Record 38 of Set 2 | port hawkesbury
# Processing Record 39 of Set 2 | izhma
# Processing Record 40 of Set 2 | port lincoln
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | pakwach
# City not found. Skipping...
# Processing Record 43 of Set 2 | sandwick
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | north bend
# Processing Record 46 of Set 2 | hami
# Processing Record 47 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | talnakh
# Processing Record 50 of Set 2 | waw
# Processing Record 1 of Set 3 | amarpur
# Processing Record 2 of Set 3 | raudeberg
# Processing Record 3 of Set 3 | bandarbeyla
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | aklavik
# Processing Record 6 of Set 3 | biltine
# Processing Record 7 of Set 3 | lakes entrance
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | sabha
# Processing Record 12 of Set 3 | high level
# Processing Record 13 of Set 3 | alice springs
# Processing Record 14 of Set 3 | leningradskiy
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | kieta
# Processing Record 17 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 3 | takestan
# Processing Record 19 of Set 3 | marsh harbour
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | winslow
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | ribeira grande
# Processing Record 24 of Set 3 | midland
# Processing Record 25 of Set 3 | mandiana
# Processing Record 26 of Set 3 | norman wells
# Processing Record 27 of Set 3 | bambous virieux
# Processing Record 28 of Set 3 | itarema
# Processing Record 29 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | kimbe
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | porto novo
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | westport
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | tahta
# Processing Record 41 of Set 3 | geraldton
# Processing Record 42 of Set 3 | juegang
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 3 | santiago
# Processing Record 47 of Set 3 | fairbanks
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | cayenne
# Processing Record 50 of Set 3 | chuguyevka
# Processing Record 1 of Set 4 | waitara
# Processing Record 2 of Set 4 | ambon
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | suntar
# Processing Record 6 of Set 4 | terra santa
# Processing Record 7 of Set 4 | los llanos de aridane
# Processing Record 8 of Set 4 | maltahohe
# Processing Record 9 of Set 4 | martapura
# Processing Record 10 of Set 4 | souillac
# Processing Record 11 of Set 4 | chase
# Processing Record 12 of Set 4 | coihaique
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | bathsheba
# Processing Record 16 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 4 | mount isa
# Processing Record 18 of Set 4 | methoni
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | tongzi
# Processing Record 21 of Set 4 | deputatskiy
# Processing Record 22 of Set 4 | bartica
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 4 | tessalit
# Processing Record 26 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | saint-pierre
# Processing Record 29 of Set 4 | flinders
# Processing Record 30 of Set 4 | nouadhibou
# Processing Record 31 of Set 4 | lavrentiya
# Processing Record 32 of Set 4 | trairi
# Processing Record 33 of Set 4 | kirkwall
# Processing Record 34 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 37 of Set 4 | sur
# Processing Record 38 of Set 4 | kuching
# Processing Record 39 of Set 4 | cape town
# Processing Record 40 of Set 4 | salalah
# Processing Record 41 of Set 4 | pouebo
# Processing Record 42 of Set 4 | svobodnyy
# Processing Record 43 of Set 4 | totness
# Processing Record 44 of Set 4 | klaksvik
# Processing Record 45 of Set 4 | dunedin
# Processing Record 46 of Set 4 | khash
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | langsa
# Processing Record 49 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | ambulu
# Processing Record 2 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | pechora
# Processing Record 5 of Set 5 | sompeta
# Processing Record 6 of Set 5 | mar del plata
# Processing Record 7 of Set 5 | seoul
# Processing Record 8 of Set 5 | jiaozuo
# Processing Record 9 of Set 5 | cidreira
# Processing Record 10 of Set 5 | bakchar
# Processing Record 11 of Set 5 | bolshaya dzhalga
# Processing Record 12 of Set 5 | tamandare
# Processing Record 13 of Set 5 | guerrero negro
# Processing Record 14 of Set 5 | katsuura
# Processing Record 15 of Set 5 | gogrial
# Processing Record 16 of Set 5 | duluth
# Processing Record 17 of Set 5 | asmara
# Processing Record 18 of Set 5 | nyurba
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | palmer
# Processing Record 21 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 22 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | upernavik
# Processing Record 24 of Set 5 | gloversville
# Processing Record 25 of Set 5 | yashkul
# Processing Record 26 of Set 5 | staroutkinsk
# Processing Record 27 of Set 5 | hay river
# Processing Record 28 of Set 5 | ayer tawar
# Processing Record 29 of Set 5 | odessa
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 5 | tongliao
# Processing Record 32 of Set 5 | skjervoy
# Processing Record 33 of Set 5 | angoche
# Processing Record 34 of Set 5 | komsomolskiy
# Processing Record 35 of Set 5 | rawson
# Processing Record 36 of Set 5 | kruisfontein
# Processing Record 37 of Set 5 | urusha
# Processing Record 38 of Set 5 | rantepao
# Processing Record 39 of Set 5 | kyshtovka
# Processing Record 40 of Set 5 | boca do acre
# Processing Record 41 of Set 5 | blessington
# Processing Record 42 of Set 5 | samfya
# Processing Record 43 of Set 5 | pacific grove
# Processing Record 44 of Set 5 | soe
# Processing Record 45 of Set 5 | ust-barguzin
# Processing Record 46 of Set 5 | marathon
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 5 | constitucion
# Processing Record 49 of Set 5 | valparaiso
# Processing Record 50 of Set 5 | west bay
# Processing Record 1 of Set 6 | thompson
# Processing Record 2 of Set 6 | algiers
# Processing Record 3 of Set 6 | arlit
# Processing Record 4 of Set 6 | saldanha
# Processing Record 5 of Set 6 | esperance
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | niteroi
# Processing Record 8 of Set 6 | castro
# Processing Record 9 of Set 6 | torbay
# Processing Record 10 of Set 6 | mitu
# Processing Record 11 of Set 6 | teknaf
# Processing Record 12 of Set 6 | bahar
# Processing Record 13 of Set 6 | aranos
# Processing Record 14 of Set 6 | namibe
# Processing Record 15 of Set 6 | abakaliki
# Processing Record 16 of Set 6 | acapulco
# Processing Record 17 of Set 6 | codrington
# Processing Record 18 of Set 6 | baracoa
# Processing Record 19 of Set 6 | montbrison
# Processing Record 20 of Set 6 | nikolskoye
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | wanning
# Processing Record 23 of Set 6 | chokurdakh
# Processing Record 24 of Set 6 | anadyr
# Processing Record 25 of Set 6 | martinsburg
# Processing Record 26 of Set 6 | ulladulla
# Processing Record 27 of Set 6 | bhandaria
# Processing Record 28 of Set 6 | provideniya
# Processing Record 29 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 6 | kirakira
# Processing Record 31 of Set 6 | minab
# Processing Record 32 of Set 6 | orlik
# Processing Record 33 of Set 6 | kargasok
# Processing Record 34 of Set 6 | goma
# Processing Record 35 of Set 6 | esmeraldas
# Processing Record 36 of Set 6 | hovd
# Processing Record 37 of Set 6 | christchurch
# Processing Record 38 of Set 6 | caledon
# Processing Record 39 of Set 6 | jacareacanga
# Processing Record 40 of Set 6 | turbiv
# Processing Record 41 of Set 6 | berlevag
# Processing Record 42 of Set 6 | umm kaddadah
# Processing Record 43 of Set 6 | calama
# Processing Record 44 of Set 6 | palana
# Processing Record 45 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 6 | ergani
# Processing Record 47 of Set 6 | meadow lake
# Processing Record 48 of Set 6 | kalmunai
# Processing Record 49 of Set 6 | makakilo city
# Processing Record 50 of Set 6 | severnyy
# Processing Record 1 of Set 7 | tirumullaivasal
# Processing Record 2 of Set 7 | cabo san lucas
# Processing Record 3 of Set 7 | dwarka
# Processing Record 4 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 5 of Set 7 | margate
# Processing Record 6 of Set 7 | airai
# Processing Record 7 of Set 7 | kununurra
# Processing Record 8 of Set 7 | ghanzi
# Processing Record 9 of Set 7 | hjelset
# Processing Record 10 of Set 7 | tandalti
# Processing Record 11 of Set 7 | ialibu
# Processing Record 12 of Set 7 | vila
# Processing Record 13 of Set 7 | georgetown
# Processing Record 14 of Set 7 | saint-augustin
# Processing Record 15 of Set 7 | andijon
# Processing Record 16 of Set 7 | hervey bay
# Processing Record 17 of Set 7 | michigan city
# Processing Record 18 of Set 7 | tateyama
# Processing Record 19 of Set 7 | camabatela
# Processing Record 20 of Set 7 | ravar
# Processing Record 21 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 7 | tuatapere
# Processing Record 23 of Set 7 | okha
# Processing Record 24 of Set 7 | khujner
# Processing Record 25 of Set 7 | zavetnoye
# Processing Record 26 of Set 7 | qinhuangdao
# Processing Record 27 of Set 7 | sambava
# Processing Record 28 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 7 | dingzhou
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | khani
# Processing Record 32 of Set 7 | olafsvik
# Processing Record 33 of Set 7 | atar
# Processing Record 34 of Set 7 | owen sound
# Processing Record 35 of Set 7 | kalynivka
# Processing Record 36 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 37 of Set 7 | kislovodsk
# Processing Record 38 of Set 7 | la ronge
# Processing Record 39 of Set 7 | mastic beach
# Processing Record 40 of Set 7 | mackenzie
# Processing Record 41 of Set 7 | mayo
# Processing Record 42 of Set 7 | oromocto
# Processing Record 43 of Set 7 | tahe
# Processing Record 44 of Set 7 | xingtai
# Processing Record 45 of Set 7 | broome
# Processing Record 46 of Set 7 | middleton
# Processing Record 47 of Set 7 | benghazi
# Processing Record 48 of Set 7 | xining
# Processing Record 49 of Set 7 | yevsino
# Processing Record 50 of Set 7 | cockburn town
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | lazaro cardenas
# Processing Record 3 of Set 8 | iralaya
# Processing Record 4 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 8 | shediac
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | alofi
# Processing Record 8 of Set 8 | nanortalik
# Processing Record 9 of Set 8 | lebanon
# Processing Record 10 of Set 8 | ketchikan
# Processing Record 11 of Set 8 | kolondieba
# Processing Record 12 of Set 8 | nioro
# Processing Record 13 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 14 of Set 8 | markova
# Processing Record 15 of Set 8 | fortuna
# Processing Record 16 of Set 8 | karratha
# Processing Record 17 of Set 8 | dunda
# Processing Record 18 of Set 8 | ilulissat
# Processing Record 19 of Set 8 | karaton
# Processing Record 20 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 8 | bonga
# Processing Record 22 of Set 8 | asau
# Processing Record 23 of Set 8 | axim
# Processing Record 24 of Set 8 | kahului
# Processing Record 25 of Set 8 | luangwa
# Processing Record 26 of Set 8 | te anau
# Processing Record 27 of Set 8 | qui nhon
# Processing Record 28 of Set 8 | salta
# Processing Record 29 of Set 8 | biak
# Processing Record 30 of Set 8 | laguna
# Processing Record 31 of Set 8 | northam
# Processing Record 32 of Set 8 | padang
# Processing Record 33 of Set 8 | cordoba
# Processing Record 34 of Set 8 | burnie
# Processing Record 35 of Set 8 | vanderhoof
# Processing Record 36 of Set 8 | sassandra
# Processing Record 37 of Set 8 | nizhnekamsk
# Processing Record 38 of Set 8 | talaya
# Processing Record 39 of Set 8 | hit
# Processing Record 40 of Set 8 | two rivers
# Processing Record 41 of Set 8 | yabelo
# Processing Record 42 of Set 8 | serenje
# Processing Record 43 of Set 8 | ribeira brava
# Processing Record 44 of Set 8 | tawang
# Processing Record 45 of Set 8 | san antonio
# Processing Record 46 of Set 8 | denpasar
# Processing Record 47 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 48 of Set 8 | port hardy
# Processing Record 49 of Set 8 | lorengau
# Processing Record 50 of Set 8 | bowen
# Processing Record 1 of Set 9 | san policarpo
# Processing Record 2 of Set 9 | kodinsk
# Processing Record 3 of Set 9 | kaseda
# Processing Record 4 of Set 9 | zambezi
# Processing Record 5 of Set 9 | tiarei
# Processing Record 6 of Set 9 | melton
# Processing Record 7 of Set 9 | san jose
# Processing Record 8 of Set 9 | hanzhong
# Processing Record 9 of Set 9 | dingle
# Processing Record 10 of Set 9 | cheremshanka
# Processing Record 11 of Set 9 | kungurtug
# Processing Record 12 of Set 9 | ende
# Processing Record 13 of Set 9 | flin flon
# Processing Record 14 of Set 9 | quatre cocos
# Processing Record 15 of Set 9 | sarrebourg
# Processing Record 16 of Set 9 | pisco
# Processing Record 17 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 9 | poya
# Processing Record 19 of Set 9 | ilebo
# Processing Record 20 of Set 9 | panorama
# Processing Record 21 of Set 9 | klyuchi
# Processing Record 22 of Set 9 | cabadiangan
# Processing Record 23 of Set 9 | jinxiang
# Processing Record 24 of Set 9 | byron bay
# Processing Record 25 of Set 9 | sarkand
# Processing Record 26 of Set 9 | khislavichi
# Processing Record 27 of Set 9 | tutoia
# Processing Record 28 of Set 9 | zharkent
# Processing Record 29 of Set 9 | yucaipa
# Processing Record 30 of Set 9 | san ramon
# Processing Record 31 of Set 9 | greytown
# Processing Record 32 of Set 9 | cabo rojo
# Processing Record 33 of Set 9 | victor harbor
# Processing Record 34 of Set 9 | plastun
# Processing Record 35 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 36 of Set 9 | shangrao
# Processing Record 37 of Set 9 | tokur
# Processing Record 38 of Set 9 | severnoye
# Processing Record 39 of Set 9 | kongolo
# Processing Record 40 of Set 9 | andenes
# Processing Record 41 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 9 | sundsvall
# Processing Record 43 of Set 9 | normandin
# Processing Record 44 of Set 9 | ushtobe
# Processing Record 45 of Set 9 | inongo
# Processing Record 46 of Set 9 | praxedis guerrero
# Processing Record 47 of Set 9 | gillette
# Processing Record 48 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 9 | ponta delgada
# Processing Record 50 of Set 9 | puerto el triunfo
# Processing Record 1 of Set 10 | lata
# Processing Record 2 of Set 10 | skibbereen
# Processing Record 3 of Set 10 | belaya gora
# Processing Record 4 of Set 10 | kilindoni
# Processing Record 5 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 10 | antofagasta
# Processing Record 7 of Set 10 | bezhetsk
# Processing Record 8 of Set 10 | naze
# Processing Record 9 of Set 10 | cap malheureux
# Processing Record 10 of Set 10 | kursk
# Processing Record 11 of Set 10 | alekseyevka
# Processing Record 12 of Set 10 | walvis bay
# Processing Record 13 of Set 10 | osmaniye
# Processing Record 14 of Set 10 | bonavista
# Processing Record 15 of Set 10 | beeville
# Processing Record 16 of Set 10 | camana
# Processing Record 17 of Set 10 | comodoro rivadavia
# Processing Record 18 of Set 10 | panshi
# Processing Record 19 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 10 | akdepe
# Processing Record 21 of Set 10 | bichena
# Processing Record 22 of Set 10 | luanda
# Processing Record 23 of Set 10 | springbok
# Processing Record 24 of Set 10 | kayerkan
# Processing Record 25 of Set 10 | iqaluit
# Processing Record 26 of Set 10 | hwange
# Processing Record 27 of Set 10 | maine-soroa
# Processing Record 28 of Set 10 | umm lajj
# Processing Record 29 of Set 10 | yarega
# Processing Record 30 of Set 10 | inirida
# Processing Record 31 of Set 10 | gizo
# Processing Record 32 of Set 10 | paoua
# Processing Record 33 of Set 10 | ilinskiy
# Processing Record 34 of Set 10 | nokaneng
# Processing Record 35 of Set 10 | takob
# City not found. Skipping...
# Processing Record 36 of Set 10 | sept-iles
# Processing Record 37 of Set 10 | mbandaka
# Processing Record 38 of Set 10 | lodja
# Processing Record 39 of Set 10 | oranjemund
# Processing Record 40 of Set 10 | coos bay
# Processing Record 41 of Set 10 | dzaoudzi
# Processing Record 42 of Set 10 | meiganga
# Processing Record 43 of Set 10 | praia
# Processing Record 44 of Set 10 | wanxian
# Processing Record 45 of Set 10 | pirovskoye
# Processing Record 46 of Set 10 | neiafu
# Processing Record 47 of Set 10 | ust-kulom
# Processing Record 48 of Set 10 | pavlovskiy
# Processing Record 49 of Set 10 | mikuni
# Processing Record 50 of Set 10 | sao mateus
# Processing Record 1 of Set 11 | camacha
# Processing Record 2 of Set 11 | new iberia
# Processing Record 3 of Set 11 | nadym
# Processing Record 4 of Set 11 | huambo
# Processing Record 5 of Set 11 | dover
# Processing Record 6 of Set 11 | steamboat springs
# Processing Record 7 of Set 11 | celendin
# Processing Record 8 of Set 11 | ust-maya
# Processing Record 9 of Set 11 | gorontalo
# Processing Record 10 of Set 11 | muravlenko
# Processing Record 11 of Set 11 | gushikawa
# Processing Record 12 of Set 11 | faya
# Processing Record 13 of Set 11 | yar-sale
# Processing Record 14 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 11 | kropotkin
# Processing Record 16 of Set 11 | turtas
# Processing Record 17 of Set 11 | gorkovskiy
# Processing Record 18 of Set 11 | takapau
# Processing Record 19 of Set 11 | tokmak
# Processing Record 20 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 11 | soyo
# Processing Record 22 of Set 11 | rocha
# Processing Record 23 of Set 11 | vanimo
# Processing Record 24 of Set 11 | miyako
# Processing Record 25 of Set 11 | tolaga bay
# Processing Record 26 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 11 | koslan
# Processing Record 28 of Set 11 | fuerte olimpo
# Processing Record 29 of Set 11 | santa cruz
# Processing Record 30 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 31 of Set 11 | sainte-marie
# Processing Record 32 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 11 | salekhard
# Processing Record 34 of Set 11 | boli
# Processing Record 35 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 11 | morgan city
# Processing Record 37 of Set 11 | san cristobal
# Processing Record 38 of Set 11 | banda aceh
# Processing Record 39 of Set 11 | maldonado
# Processing Record 40 of Set 11 | half moon bay
# Processing Record 41 of Set 11 | del rio
# Processing Record 42 of Set 11 | atlantic city
# Processing Record 43 of Set 11 | xuanwu
# Processing Record 44 of Set 11 | batavia
# Processing Record 45 of Set 11 | kampene
# Processing Record 46 of Set 11 | pandamatenga
# Processing Record 47 of Set 11 | sistranda
# Processing Record 48 of Set 11 | puerto escondido
# Processing Record 49 of Set 11 | sungaipenuh
# Processing Record 50 of Set 11 | majene
# Processing Record 1 of Set 12 | katunino
# Processing Record 2 of Set 12 | vila velha
# Processing Record 3 of Set 12 | chapais
# Processing Record 4 of Set 12 | kokstad
# Processing Record 5 of Set 12 | verkhoyansk
# Processing Record 6 of Set 12 | zhaozhou
# Processing Record 7 of Set 12 | adre
# Processing Record 8 of Set 12 | moncton
# Processing Record 9 of Set 12 | san quintin
# Processing Record 10 of Set 12 | misratah
# Processing Record 11 of Set 12 | montagnana
# Processing Record 12 of Set 12 | sangin
# Processing Record 13 of Set 12 | havoysund
# Processing Record 14 of Set 12 | grindavik
# Processing Record 15 of Set 12 | polunochnoye
# Processing Record 16 of Set 12 | bandiagara
# Processing Record 17 of Set 12 | arroyo
# Processing Record 18 of Set 12 | tautira
# Processing Record 19 of Set 12 | mastung
# Processing Record 20 of Set 12 | saint anthony
# Processing Record 21 of Set 12 | gallup
# Processing Record 22 of Set 12 | teya
# Processing Record 23 of Set 12 | rio cuarto
# Processing Record 24 of Set 12 | merauke
# Processing Record 25 of Set 12 | bitung
# Processing Record 26 of Set 12 | vrangel
# Processing Record 27 of Set 12 | ukiah
# Processing Record 28 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 12 | eureka
# Processing Record 30 of Set 12 | ereymentau
# Processing Record 31 of Set 12 | vostok
# Processing Record 32 of Set 12 | ayan
# Processing Record 33 of Set 12 | ridgecrest
# Processing Record 34 of Set 12 | meulaboh
# Processing Record 35 of Set 12 | sakata
# Processing Record 36 of Set 12 | roma
# Processing Record 37 of Set 12 | abu samrah
# Processing Record 38 of Set 12 | vicosa do ceara
# Processing Record 39 of Set 12 | mitsamiouli
# Processing Record 40 of Set 12 | hoquiam
# Processing Record 41 of Set 12 | pailon
# Processing Record 42 of Set 12 | pontianak
# Processing Record 43 of Set 12 | yurga
# Processing Record 44 of Set 12 | black river
# Processing Record 45 of Set 12 | bara
# Processing Record 46 of Set 12 | kalabo
# Processing Record 47 of Set 12 | tigil
# Processing Record 48 of Set 12 | beira
# Processing Record 49 of Set 12 | gulmarg
# Processing Record 50 of Set 12 | ampanihy
# Processing Record 1 of Set 13 | wajima
# Processing Record 2 of Set 13 | pangnirtung
# Processing Record 3 of Set 13 | juneau
# Processing Record 4 of Set 13 | stephanskirchen
# Processing Record 5 of Set 13 | barra do bugres
# Processing Record 6 of Set 13 | ekuvukeni
# Processing Record 7 of Set 13 | kloulklubed
# Processing Record 8 of Set 13 | hofn
# Processing Record 9 of Set 13 | bubaque
# Processing Record 10 of Set 13 | sivaki
# Processing Record 11 of Set 13 | matane
# Processing Record 12 of Set 13 | quetzaltepec
# City not found. Skipping...
# Processing Record 13 of Set 13 | newberry
# Processing Record 14 of Set 13 | storforshei
# Processing Record 15 of Set 13 | mendoza
# Processing Record 16 of Set 13 | providencia
# Processing Record 17 of Set 13 | mtinko
# Processing Record 18 of Set 13 | borogontsy
# Processing Record 19 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 13 | chardara
# Processing Record 21 of Set 13 | komatipoort
# Processing Record 22 of Set 13 | launceston
# Processing Record 23 of Set 13 | rehoboth
# Processing Record 24 of Set 13 | eregli
# Processing Record 25 of Set 13 | patrocinio
# Processing Record 26 of Set 13 | hirado
# Processing Record 27 of Set 13 | werda
# Processing Record 28 of Set 13 | khartoum
# Processing Record 29 of Set 13 | manicore
# Processing Record 30 of Set 13 | payakumbuh
# Processing Record 31 of Set 13 | sitka
# Processing Record 32 of Set 13 | russellville
# Processing Record 33 of Set 13 | bolshaya atnya
# City not found. Skipping...
# Processing Record 34 of Set 13 | srednekolymsk
# Processing Record 35 of Set 13 | eyl
# Processing Record 36 of Set 13 | aykhal
# Processing Record 37 of Set 13 | roald
# Processing Record 38 of Set 13 | sao jose da coroa grande
# Processing Record 39 of Set 13 | ust-nera
# Processing Record 40 of Set 13 | virginia beach
# Processing Record 41 of Set 13 | dungarpur
# Processing Record 42 of Set 13 | gao
# Processing Record 43 of Set 13 | saint-felicien
# Processing Record 44 of Set 13 | necochea
# Processing Record 45 of Set 13 | yunyang
# Processing Record 46 of Set 13 | florianopolis
# Processing Record 47 of Set 13 | zhangye
# Processing Record 48 of Set 13 | oum hadjer
# Processing Record 49 of Set 13 | puqi
# Processing Record 50 of Set 13 | solnechnyy
# Processing Record 1 of Set 14 | lerik
# Processing Record 2 of Set 14 | hamilton
# Processing Record 3 of Set 14 | sinnamary
# Processing Record 4 of Set 14 | semey
# Processing Record 5 of Set 14 | gat
# Processing Record 6 of Set 14 | denia
# Processing Record 7 of Set 14 | kryve ozero
# Processing Record 8 of Set 14 | pitimbu
# Processing Record 9 of Set 14 | road town
# Processing Record 10 of Set 14 | nouakchott
# Processing Record 11 of Set 14 | luwuk
# Processing Record 12 of Set 14 | jiaojiang
# Processing Record 13 of Set 14 | maragogi
# Processing Record 14 of Set 14 | revelstoke
# Processing Record 15 of Set 14 | chivacoa
# Processing Record 16 of Set 14 | buin
# Processing Record 17 of Set 14 | rancho palos verdes
# Processing Record 18 of Set 14 | quzhou
# Processing Record 19 of Set 14 | panama city
# Processing Record 20 of Set 14 | husavik
# Processing Record 21 of Set 14 | puruaran
# Processing Record 22 of Set 14 | nuevitas
# Processing Record 23 of Set 14 | bunia
# Processing Record 24 of Set 14 | turayf
# Processing Record 25 of Set 14 | kombissiri
# Processing Record 26 of Set 14 | oppdal
# Processing Record 27 of Set 14 | batagay-alyta
# Processing Record 28 of Set 14 | kotelnich
# Processing Record 29 of Set 14 | dobryanka
# Processing Record 30 of Set 14 | henties bay
# Processing Record 31 of Set 14 | kaupanger
# Processing Record 32 of Set 14 | dicabisagan
# Processing Record 33 of Set 14 | ixtapa
# Processing Record 34 of Set 14 | samana
# Processing Record 35 of Set 14 | akhtyrskiy
# Processing Record 36 of Set 14 | seydisehir
# Processing Record 37 of Set 14 | arman
# Processing Record 38 of Set 14 | kibungo
# Processing Record 39 of Set 14 | barra do garcas
# Processing Record 40 of Set 14 | storslett
# Processing Record 41 of Set 14 | lobez
# Processing Record 42 of Set 14 | barreirinhas
# Processing Record 43 of Set 14 | akyab
# Processing Record 44 of Set 14 | shache
# Processing Record 45 of Set 14 | kavaratti
# Processing Record 46 of Set 14 | mogadishu
# Processing Record 47 of Set 14 | marsa matruh
# Processing Record 48 of Set 14 | karpogory
# Processing Record 49 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 14 | goba
# Processing Record 1 of Set 15 | chadiza
# Processing Record 2 of Set 15 | matongo
# Processing Record 3 of Set 15 | vicuna
# Processing Record 4 of Set 15 | mocuba
# Processing Record 5 of Set 15 | qinzhou
# Processing Record 6 of Set 15 | kadykchan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 654

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ahipara -35.1667  173.1667     58.95        73         100
# 1         Cervo  43.6702   -7.4101     60.94        70           0
# 2       Rikitea -23.1203 -134.9692     70.59        61          77
# 3         Gamba  -2.6500   10.0000     74.46        85          96
# 4          Uvat  59.1433   68.8953     43.11        94           9
# 5           Ayr  55.4627   -4.6339     58.32        88          75
# 6  Punta Arenas -53.1500  -70.9167     42.91        81          75
# 7      Bushenyi  -0.5853   30.2114     58.28        97          97
# 8   Sete Lagoas -19.4658  -44.2467     67.08        90         100
# 9          Hilo  19.7297 -155.0900     83.25        74          75
#
#    Wind Speed Country      Description
# 0       14.81      NZ  overcast clouds
# 1        2.84      ES        clear sky
# 2       24.14      PF    broken clouds
# 3        4.90      GA  overcast clouds
# 4        4.14      RU        clear sky
# 5       20.71      GB       light rain
# 6       12.66      CL    broken clouds
# 7        1.90      UG  overcast clouds
# 8        3.00      BR  overcast clouds
# 9        9.22      US    broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"


# Recreate the DataFrame by using the new column order
city_data_df.rename(columns={'Description': 'Current Description'}, inplace=True)

city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]].copy()
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ahipara      NZ -35.1667  173.1667     58.95        73         100
# 1         Cervo      ES  43.6702   -7.4101     60.94        70           0
# 2       Rikitea      PF -23.1203 -134.9692     70.59        61          77
# 3         Gamba      GA  -2.6500   10.0000     74.46        85          96
# 4          Uvat      RU  59.1433   68.8953     43.11        94           9
# 5           Ayr      GB  55.4627   -4.6339     58.32        88          75
# 6  Punta Arenas      CL -53.1500  -70.9167     42.91        81          75
# 7      Bushenyi      UG  -0.5853   30.2114     58.28        97          97
# 8   Sete Lagoas      BR -19.4658  -44.2467     67.08        90         100
# 9          Hilo      US  19.7297 -155.0900     83.25        74          75
#
#    Wind Speed Current Description
# 0       14.81     overcast clouds
# 1        2.84           clear sky
# 2       24.14       broken clouds
# 3        4.90     overcast clouds
# 4        4.14           clear sky
# 5       20.71          light rain
# 6       12.66       broken clouds
# 7        1.90     overcast clouds
# 8        3.00     overcast clouds
# 9        9.22       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
weather_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(weather_file)
